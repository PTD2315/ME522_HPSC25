# %%
import matplotlib.pyplot as plt

# Data for the plot
x = [0, 1, 2, 3, 4, 5]
y = [0, 1, 4, 9, 16, 25]

# Create the plot
plt.plot(x, y)

# Label the axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Title of the plot
plt.title('Simple x-y plot')

# Display the plot
plt.show()
